# %%
import pickle
from matplotlib import pyplot as plt

# %%
xy = pickle.load(open('/home/maspe/filer/SERT/ALL/npys/xy_WT.dict', 'rb'))

# %%
x = xy['SERT1597'][0] / max(xy['SERT1597'][0])
y = xy['SERT1597'][1] / max(xy['SERT1597'][1])

# %%
plt.plot(x,y)

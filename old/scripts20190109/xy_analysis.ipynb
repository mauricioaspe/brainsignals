# %%
### Importing modules
import time
import pickle
import numpy as np
import pandas as pd
from matplotlib import cm
from matplotlib import pyplot as plt
from scipy import signal

# %% [markdown]
# ###############

# %%
morlets_WT = pickle.load(open('/home/maspe/filer/SERT/ALL/npys/theta_morlets_WT.dict'))

# %%
morlets_WT['mPFC']
# Out:
# {u'SERT1597': array([3982.76461681, 3950.1060242 , 3918.27858985, ..., 4085.48204001,
#         4050.47791677, 4016.23021805])}

# %%
spectrum = morlets_WT['mPFC']['SERT1597']

# %%
test = signal.resample(x=spectrum, num=18000)
test.shape
# Out:
# (18000,)

# %%
df = pd.read_csv('/home/maspe/filer/xy/SERT1597OF_WT.csv', header=None)
#start = int(df[7][0])
#stop = int(df[7][1])

# %%
x = df[1].to_numpy()
y = df[2].to_numpy()

plt.plot(x,y)

# %%
c[1]
# Out:
# array([0.        , 0.        , 0.58912656, 1.        ])

# %%
norm_test = (test[12000:] - np.min(test[12000:])) / (np.max(test[12000:]) - np.min(test[12000:]))

# %%
plt.scatter(x[12001:], y[12001:], s=16, c=norm_test, cmap='jet', alpha=0.3)
